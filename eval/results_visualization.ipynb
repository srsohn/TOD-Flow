# %%
# %load_ext autoreload
# %autoreload 2
# !cd ../src
import sys  
sys.path.insert(0, '../src')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#
DATASET = 'SGD' if mode <10 else 'MultiWOZ'
SPLIT = 'val' if DATASET == 'SGD' else 'test'
GT_DIR = f'../datasets/{DATASET}/action_prediction_gt_labels_{SPLIT}_only'
GT_GRAPH_DIR = f'../datasets/{DATASET}/gt_graph'
INF_GRAPH_DIR = f'../datasets/{DATASET}/inferred_graph'
FILTER="*"
rows = ['model', 'graph']
columns = ['postprocess']
USE_NEG_PCOND = False

if mode % 10 == 1:
    # Graph method comparison on SGD on all the models w/ single/multi sampling.
    PREDICTIONS_DIR = f'../outputs/FINAL_{DATASET}_single_multi_sample/'
    GRAPH_ALG_NAMES = ["MaxRILP", "SKRILP"]
elif mode % 10 == 2:
    INF_GRAPH_DIR = f'../datasets/{DATASET}/{GRAPH_ALG_NAME}_hparam_search/trial{EXP_NUM}'
    PREDICTIONS_DIR = f'../outputs/FINAL_{DATASET}_single_multi_sample/'
elif mode % 10 == 3:
    USE_NEG_PCOND = True
    GRAPH_ALG_NAME = "SKRILP"
    INF_GRAPH_DIR = f'../datasets/{DATASET}/inferred_graph'
    PREDICTIONS_DIR = f'../outputs/FINAL_{DATASET}_single_multi_sample/'
    NEG_HPARAM="b1e-03_th3e-05"

# %%
from pathlib import Path
import json
import os
import warnings
from tqdm import tqdm

import numpy as np
import pandas as pd

# %% [markdown]
# ## Find and organize the predictions by the models

# %%
domains = set()
models = set()
prompts = set()

# %%
len(list(Path(PREDICTIONS_DIR).glob(FILTER)))
# Out:
# 96

# %%
predictions, mapped_predictions = {}, {}
predictions_by_domain, mapped_predictions_by_domain = {}, {}
for pth in Path(PREDICTIONS_DIR).glob(FILTER):
    for config_pth in pth.glob('config*.json'):
        if 'merged' in str(config_pth):
            continue
        print(config_pth)
        try:
            with config_pth.open() as cf:
                config = json.load(cf)
        except Exception as e:
            print(f'Error while reading {config_pth}')
            print(e)
        for seed in config['seed']:
            for pred_pth in config_pth.parent.glob(f'DM_prediction_S{seed}.json'):
                dataset = config['dataset']
                if '_trajectories.json' in config['traj_path']:
                    domain = config['traj_path'].rsplit('/', 1)[-1].split('_trajectories.json')[0]
                else:
                    domain = config['traj_path'].rsplit('/', 1)[-1].split('.json')[0]
                model = config['model']
                prompt = (config['prompt_style'], config['num_shot'], config['use_mask_prompt'])
                temp = 0.0 if 'temperature' not in config else config['temperature']
                sampling = 'multi' if 'sampling' not in config else config['sampling']
                domains.add(domain)
                models.add(model)
                prompts.add(prompt)
                key = (domain, model, prompt, temp, sampling, seed)
                if temp > 1e-3 and 'merged' not in str(pred_pth):
                    continue
                try:
                    with pred_pth.open() as f:
                        predictions[key] = json.load(f)
                    predictions_by_domain[domain] = predictions[key]
                    #print(pred_pth)
                except Exception as e:
                    print(f'Error while reading {pred_pth}')
                    print(e)
                mapped_file_pth = str(pred_pth).replace("_prediction_", "_mapped_prediction_").replace(".json",".npy")
                try:
                    mapped_predictions[key] = np.load(mapped_file_pth, allow_pickle=True)
                    mapped_predictions_by_domain[domain] = mapped_predictions[key]
                except Exception as e:
                    print(f'Error while reading {mapped_file_pth}')
                    print(e)
print(f"num data: {len(mapped_predictions)}")
# Out:
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Taxi_gpt-turbo_entire-concise_5shot_T0_0515/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Attraction_flan-t5-xxl_entire-concise_5shot_T1_0524/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Hotel_flan-t5-xxl_entire-concise_5shot_T1_0524/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Hotel_flan-t5-xxl_entire-concise_5shot_T0_0510/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Taxi_gpt-turbo_entire-concise_5shot_T1_0524/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Taxi_flan-t5-xxl_entire-concise_5shot_T1_0524/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Train_gpt-turbo_entire-concise_5shot_T1_0524/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Hotel+Train_gpt-turbo_entire-concise_5shot_T1_0619/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Attraction_gpt-turbo_entire-concise_5shot_T0_0515/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Train_flan-t5-xxl_entire-concise_5shot_T1_0524/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Hotel_gpt-turbo_entire-concise_5shot_T0_0515/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant_flan-t5-xxl_entire-concise_5shot_T1_0524/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Hotel_gpt-turbo_entire-concise_5shot_T1_0524/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant_gpt-turbo_entire-concise_5shot_T1_0524/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant_gpt-turbo_entire-concise_5shot_T0_0515/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Train_gpt-turbo_entire-concise_5shot_T0_0515/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant_flan-t5-xxl_entire-concise_5shot_T0_0510/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant+Hotel_gpt-turbo_entire-concise_5shot_T1_0619/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Train_flan-t5-xxl_entire-concise_5shot_T0_0510/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Hotel+Train_gpt-turbo_entire-concise_5shot_T0_0619/config_S1636423.json
# Error while reading ../outputs/FINAL_MultiWOZ_single_multi_sample/Hotel+Train_gpt-turbo_entire-concise_5shot_T0_0619/DM_mapped_prediction_S1636423.npy
# [Errno 2] No such file or directory: '../outputs/FINAL_MultiWOZ_single_multi_sample/Hotel+Train_gpt-turbo_entire-concise_5shot_T0_0619/DM_mapped_prediction_S1636423.npy'
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Attraction_flan-t5-xxl_entire-concise_5shot_T0_0510/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant+Hotel_gpt-turbo_entire-concise_5shot_T0_0619/config_S1636423.json
# Error while reading ../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant+Hotel_gpt-turbo_entire-concise_5shot_T0_0619/DM_mapped_prediction_S1636423.npy
# [Errno 2] No such file or directory: '../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant+Hotel_gpt-turbo_entire-concise_5shot_T0_0619/DM_mapped_prediction_S1636423.npy'
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Attraction_gpt-turbo_entire-concise_5shot_T1_0524/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant+Taxi+Hotel_gpt-turbo_entire-concise_5shot_T0_0619/config_S1636423.json
# Error while reading ../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant+Taxi+Hotel_gpt-turbo_entire-concise_5shot_T0_0619/DM_mapped_prediction_S1636423.npy
# [Errno 2] No such file or directory: '../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant+Taxi+Hotel_gpt-turbo_entire-concise_5shot_T0_0619/DM_mapped_prediction_S1636423.npy'
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Taxi_flan-t5-xxl_entire-concise_5shot_T0_0510/config_S1636423.json
# ../outputs/FINAL_MultiWOZ_single_multi_sample/Restaurant+Taxi+Hotel_gpt-turbo_entire-concise_5shot_T1_0619/config_S1636423.json
# num data: 10

# %% [markdown]
# ## Load GT files and GT graphs (if available)

# %%
gt_labels = {}
# GT files
for domain in domains:
    matching = list(Path(GT_DIR).glob(f'{domain}_labels.json'))
    if len(matching) == 0:
        warnings.warn(f'{domain}: GT labels not found!')
    else:
        pth = matching[0]
        with pth.open('r') as f:
            gt_labels[domain] = json.load(f)

# %%
from util.graph_utils import get_graph_sop
from util.eval_utils import validate_trajs

gt_graphs = {}
"""
for domain in domains:
    matching = list(Path(GT_GRAPH_DIR).glob(f'*{domain}_gt_graph.npy'))
    if len(matching) == 0:
        warnings.warn(f'{domain} GT graph not found!')
    else:
        pth = matching[0]
        gt_raw = np.load(str(pth), allow_pickle=True).item()
        all_acts, all_statuses = validate_trajs(gt_labels[domain], predictions_by_domain[domain])
        gt_sop = get_graph_sop(
            gt_raw,
            subtask_list=all_statuses,
            option_list=all_acts,
        )
        graphs.setdefault(domain, {}).setdefault('GT', gt_sop)"""
#pass
# Out:
# "\nfor domain in domains:\n    matching = list(Path(GT_GRAPH_DIR).glob(f'*{domain}_gt_graph.npy'))\n    if len(matching) == 0:\n        warnings.warn(f'{domain} GT graph not found!')\n    else:\n        pth = matching[0]\n        gt_raw = np.load(str(pth), allow_pickle=True).item()\n        all_acts, all_statuses = validate_trajs(gt_labels[domain], predictions_by_domain[domain])\n        gt_sop = get_graph_sop(\n            gt_raw,\n            subtask_list=all_statuses,\n            option_list=all_acts,\n        )\n        graphs.setdefault(domain, {}).setdefault('GT', gt_sop)"

# %% [markdown]
# ## Load inferred graphs and neg precondition

# %%
def get_neg_precond_mat(neg_precond, all_acts, all_statuses):
    assert len(set(all_acts) - set(neg_precond['option_labels'])) == 0
    assert len(set(all_statuses) - set(neg_precond['subtask_labels'])) == 0
    op_inv_index = [neg_precond['option_labels'].index(s) for s in all_acts]
    su_inv_index = [neg_precond['subtask_labels'].index(s) for s in all_statuses]
    neg_precond_mat = np.stack(neg_precond['precondition_vectors'])
    neg_precond_mat = neg_precond_mat[op_inv_index, :]
    neg_precond_mat = neg_precond_mat[:, su_inv_index]
    return neg_precond_mat

# %%
load_count = 0
num_graph_per_domain = None
graphs = {}
domains_list = list(domains)
for domain in domains_list:
    # print(f'loading @ {DATASET}_{domain}*/*{GRAPH_ALG_NAME}*.npy')
    graph_algo_dict = {}
    matchings = list(Path(INF_GRAPH_DIR).glob(f'{DATASET}_{domain}*/*{GRAPH_ALG_NAME}*.npy'))
    if len(matchings) == 0:
        txt =f'{domain} inferred graph not found!'
        print(f'{INF_GRAPH_DIR}/{DATASET}_{domain}*/*{GRAPH_ALG_NAME}*.npy')
        warnings.warn(txt)
    else:
        #matchings = [matchings[0]]
        if num_graph_per_domain is None:
            num_graph_per_domain = len(matchings)
        if num_graph_per_domain !=len(matchings):
            print(f'Error! number of graphs in {domains_list[0]} and {domain} are different: {num_graph_per_domain} != {len(matchings)}')
            assert False
        for matching in matchings:
            graph_path = str(matching)
            #print(f'loading inferred graph for {domain}')
            graph_raw = np.load(graph_path, allow_pickle=True).item()
            alg_name = graph_path.split('/')[-1].replace('.npy', '')
            all_acts, all_statuses = validate_trajs(gt_labels[domain], predictions_by_domain[domain])
            graph_sop = get_graph_sop(
                graph_raw,
                subtask_list=all_statuses,
                option_list=all_acts,
            )
            if USE_NEG_PCOND:
                alg_name = alg_name + '+NEG'
                neg_precond_path = graph_path[:graph_path.rfind('/')] + f"/inferred_negative_precondition_{NEG_HPARAM}.json"
                neg_precond = json.load(open(neg_precond_path))
                neg_pcond_mat = get_neg_precond_mat(neg_precond, all_acts, all_statuses)
            else:
                neg_pcond_mat = None
            graph_algo_dict[alg_name] = (graph_sop, neg_pcond_mat)
            load_count += 1
    graphs[domain] = graph_algo_dict
print(f"Loaded {load_count} inferred graphs from {len(domains)} domains")
# Out:
# Loaded 24 inferred graphs from 24 domains

# %%
print('Loaded graphs:', {domain: vals.keys() for domain, vals in graphs.items()})
# Out:
# Loaded graphs: {'Services_2': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Calendar_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'RentalCars_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'RentalCars_2': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Buses_2': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Music_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Hotels_3': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Homes_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Movies_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Events_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Media_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Banks_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Flights_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Events_2': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Services_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Flights_2': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Restaurants_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'RideSharing_2': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Music_2': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Services_3': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Buses_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Hotels_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'RideSharing_1': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003']), 'Hotels_2': dict_keys(['inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_pos=3.0_dep=12_leaf=0.0003'])}

# %% [markdown]
# ## Calculate metrics

# %%
# need to install multiprocess, a fork of multiprocessing (built in) because of this issue:
# https://stackoverflow.com/questions/8804830/python-multiprocessing-picklingerror-cant-pickle-type-function
# !pip install multiprocess
# Out:
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 5.2 MB/s eta 0:00:01
# Collecting dill>=0.3.6
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      |████████████████████████████████| 110 kB 38.4 MB/s eta 0:00:01
# Installing collected packages: dill, multiprocess
# Successfully installed dill-0.3.6 multiprocess-0.70.14

# %%
from multiprocess import Pool# use multiprocessing to speed up evaluation!

# %%
# %%timeit -r 1 -n 1
from util.eval_utils import dact_traj_metrics_report, dact_traj_multi_sample_metrics_report, standardize_dact
from copy import deepcopy

def eval_job(args):
    pred_params, graph_params, traj = args
    domain, model, prompt_params, temp, sampling, seed = pred_params
    prompt_style, num_shot, use_mask_prompt = prompt_params
    is_multisampling = float(temp) > 0 and ('repeat' not in sampling)
    if domain not in gt_labels:
        print(f"domain not in gt_label: {domain}, {gt_labels}")
        return None
    graph_names, graph_tuples = graph_params
    graphs, neg_pcond_mats = [], []
    for graph_tuple in graph_tuples:
        if graph_tuple is not None:
            graph, neg_pcond_mat = graph_tuple
        else:
            graph, neg_pcond_mat = None, None
        graphs.append(graph)
        neg_pcond_mats.append(neg_pcond_mat)
    
    if not isinstance(traj, tuple):
        gt_processed_label_tuple = tuple(traj)
    else:
        gt_processed_label_tuple = traj
    try:
        #print(f'In {pred_params} with multisampling={is_multisampling}')
        if is_multisampling:
            report_list = dact_traj_multi_sample_metrics_report(*gt_processed_label_tuple, graph_sop=graphs, neg_precond_mat=neg_pcond_mats, verbose=False)
        else:
            report_list = dact_traj_metrics_report(*gt_processed_label_tuple, graph_sop=graphs, neg_precond_mat=neg_pcond_mats, verbose=False)
    except Exception as e:
        print(f'Error in {pred_params} {prompt_params} with multisampling={is_multisampling}')
        warnings.warn(f'Error in traj metrics: {e}')
        return None
    
    metrics_list = []
    for report, graph_name in zip(report_list, graph_names):
        stats = report['Predicted']
        post = report['post']
        metrics = {
            'domain': domain[:4]+domain[-1],
            'model': model,
            'prompt': prompt_style,
            'shot': num_shot,
            'use_mask_prompt': use_mask_prompt,
            'temp': temp,
            'sampling': sampling,
            'seed': seed,
            'graph': graph_name,    
            'precision': stats['precision'],
            'recall': stats['recall'],
            'f1': stats['f1-score'],
            'support': stats['support'],
            'postprocess': post
        }
        metrics_list.append(metrics)
    return metrics_list
    
jobs = []
for pred_params, traj_pred in mapped_predictions.items():
    domain, model, prompt_params, temp, sampling, seed = pred_params
    if temp > 0: # in case multi sampling, we cannot run without graph
        graph_list = list(graphs.get(pred_params[0], {}).items())
    else:
        graph_list = [('(None)', None)] + list(graphs.get(pred_params[0], {}).items())
    graph_names = [graph[0] for graph in graph_list]
    graph_tuples = [graph[1] for graph in graph_list]
    graph_params = (graph_names, graph_tuples)
    jobs.append((pred_params, graph_params, traj_pred))
print(f"# jobs={len(jobs)}")
with Pool(min(60, len(jobs))) as p:
    raw_metrics = [result for result in tqdm(p.imap(eval_job, jobs)) if result is not None]
#raw_metrics = [eval_job(job) for job in jobs]
metrics = []
for elem in raw_metrics:
    for metric_dict in elem:
        metrics.append(metric_dict)
print(f"output={len(metrics)}")
# Out:
# # jobs=48
# 48it [00:00, 236.57it/s]
# output=96

# %%
metrics_df = pd.DataFrame(metrics)
#metrics_df.head()

# %% [markdown]
# ### 1. Aggregated performance (averaged over schemas)

# %%
display_df = metrics_df.pivot_table(index=rows, columns=columns, values='f1', aggfunc='mean')
#display_df.round(3)

# %%
display_df
# Out:
# postprocess                                                         None
# model       graph
# flan-t5-xxl (None)                                              0.499171
#             inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_...  0.583990
# gpt-turbo   (None)                                              0.787513
#             inferred_graph_CSILP_fgam=0.8_bgam=0.95_cneg=0_...  0.835492

# %%
if mode == 12 or mode == 2:
    new_metrics = []
    for metric_dict in metrics:
        hparam_str = metric_dict['graph']
        if hparam_str == '(None)' or (metric_dict['postprocess'] != 'max' and 't5' in metric_dict['model']) or (metric_dict['postprocess'] != 'None' and 'gpt' in metric_dict['model']):
            continue
        hparam_str = hparam_str[len("inferred_graph_"):].replace('.npy', '')
        tokens = hparam_str.split('_')
        if GRAPH_ALG_NAME == 'NAILP':
            #inferred_graph_NAILP_gam=0.9_eneg=2_cneg=2_pos=1.0_bw=5_bd=1_cp=0.0_dep=8_leaf=0.01_vth=0.5_vw=0.05
            param_names = ['gamma', 'eneg', 'cneg', 'pos', 'bw', 'bd', 'cmplx', 'dep', 'leaf', 'vth', 'vw']
        elif GRAPH_ALG_NAME == 'ACCILP':
            param_names = ['gamma', 'eneg', 'cneg', 'pos', 'bw', 'bd', 'cmplx', 'dep', 'leaf', 'mss', 'minp']
        elif GRAPH_ALG_NAME == 'VARILP': # inferred_graph_VARILP_gam=0.9_eneg=2_cneg=2_pos=1.0_bw=5_bd=2_cp=0.0_dep=8_leaf=0.01_sbias=0.1_mins=0.0
            param_names = ['gamma', 'eneg', 'cneg', 'pos', 'bw', 'bd', 'cmplx', 'dep', 'leaf', 'sbias', 'mins']
        elif GRAPH_ALG_NAME == 'CSILP': # inferred_graph_CSILP_fgam=0.6_bgam=0.6_cneg=0_pos=1.0_dep=8_leaf=0.01
            param_names = ['fgam', 'bgam', 'cneg', 'pos', 'dep', 'leaf']
        elif GRAPH_ALG_NAME == 'BCILP': # inferred_graph_BCILP_cneg=0_dep=8_leaf=0.01
            param_names = ['cneg', 'dep', 'leaf']
        elif GRAPH_ALG_NAME == 'ILP': # inferred_graph_BCILP_cneg=0_dep=8_leaf=0.01
            param_names = ['dep', 'leaf']
        hparam_dict = dict(algo=tokens[0])
        for par, token in zip(param_names, tokens[1:]):
            hparam_dict[par] = token.split('=')[1]  
        metric_dict.update(hparam_dict)
        new_metrics.append(metric_dict)
    print(f'[{GRAPH_ALG_NAME}-v{EXP_NUM} @{DATASET}] num runs: {len(new_metrics)}')
    new_metrics_df = pd.DataFrame(new_metrics)
    graph_columns = param_names[1::2]
    graph_rows = param_names[::2]
    df_agg = new_metrics_df.pivot_table(index=graph_rows, columns=graph_columns, values='f1', aggfunc='mean')
    if mode >= 10:
        df_agg = df_agg - 0.3715 # subtract SKRILP performance
    else:
        df_agg = df_agg - 0.679 # subtract SKRILP performance
    display(df_agg.round(decimals=3))

# %%
if mode % 10 == 2:
    for hparam_label in param_names:
        new_df = new_metrics_df.groupby(hparam_label).agg('mean', numeric_only=True)['f1'].to_frame()
        if mode >=10:
            new_df = new_df - 0.3715 # subtract SKRILP performance
        else:
            new_df = new_df - 0.679 # subtract SKRILP performance
        if len(new_df.index) == 1 or hparam_label == 'model':
            continue
        display(new_df.T.round(decimals=3))

# %%
mode = 12 # 2: SGD / 12: MW
EXP_NUM = 17
GRAPH_ALG_NAME = 'CSILP' # NAILP ACCILP VARILP CSILP

# %%
graph_columns = ['model'] + param_names[1::2]
graph_columns = param_names[1::2]
graph_rows = ['model'] + param_names[::2]
df_agg2 = new_metrics_df.pivot_table(index=graph_rows, columns=graph_columns, values='f1', aggfunc='mean')
display(df_agg2.round(decimals=3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/paul/yiwei/dialog_flow/ipynb/results_visualization.ipynb Cell 25 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bpliang.pc.cs.cmu.edu/home/paul/yiwei/dialog_flow/ipynb/results_visualization.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> graph_columns = ['model'] + param_names[1::2]
#       <a href='vscode-notebook-cell://ssh-remote%2Bpliang.pc.cs.cmu.edu/home/paul/yiwei/dialog_flow/ipynb/results_visualization.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> graph_columns = param_names[1::2]
#       <a href='vscode-notebook-cell://ssh-remote%2Bpliang.pc.cs.cmu.edu/home/paul/yiwei/dialog_flow/ipynb/results_visualization.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> graph_rows = ['model'] + param_names[::2]
#
# NameError: name 'param_names' is not defined

# %% [markdown]
# ### 2. schema-wise performance

# %%
from IPython.display import display
display_df = metrics_df.pivot(index=rows+columns, columns=['domain'], values='f1')
display_df = display_df.round(3)
num_columns = len(display_df.columns)
if num_columns > 12:
    df1 = display_df.iloc[:, :num_columns//2]
    df2 = display_df.iloc[:, num_columns//2:]
    display(df1)
    display(df2)
else:
    display(display_df)
# Out:
# domain                                                                      Attrn  \
# model       graph                                              postprocess
# flan-t5-xxl (None)                                             None         0.495
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.509
#                                                                max          0.503
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.526
#                                                                max          0.527
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.543
#                                                                max          0.581
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.543
#                                                                max          0.601
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.549
#                                                                max          0.556
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.543
#                                                                max          0.547
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.526
#                                                                max          0.595
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.543
#                                                                max          0.632
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.552
#                                                                max          0.551
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.540
#                                                                max          0.533
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.537
#                                                                max          0.584
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.537
#                                                                max          0.574
# gpt-turbo   (None)                                             None         0.626
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.630
#                                                                max          0.428
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.634
#                                                                max          0.418
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.660
#                                                                max          0.518
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.663
#                                                                max          0.518
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.670
#                                                                max          0.500
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.646
#                                                                max          0.461
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.635
#                                                                max          0.440
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.657
#                                                                max          0.485
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.650
#                                                                max          0.486
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.636
#                                                                max          0.494
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.644
#                                                                max          0.526
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.650
#                                                                max          0.532
#
# domain                                                                      Hotel  \
# model       graph                                              postprocess
# flan-t5-xxl (None)                                             None         0.160
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.128
#                                                                max          0.244
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.120
#                                                                max          0.251
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.116
#                                                                max          0.265
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.109
#                                                                max          0.256
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.115
#                                                                max          0.234
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.109
#                                                                max          0.266
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.117
#                                                                max          0.271
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.120
#                                                                max          0.278
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.108
#                                                                max          0.254
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.109
#                                                                max          0.259
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.114
#                                                                max          0.270
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.116
#                                                                max          0.276
# gpt-turbo   (None)                                             None         0.370
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.376
#                                                                max          0.296
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.379
#                                                                max          0.261
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.374
#                                                                max          0.259
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.365
#                                                                max          0.258
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.377
#                                                                max          0.286
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.385
#                                                                max          0.256
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.393
#                                                                max          0.270
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.399
#                                                                max          0.286
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.378
#                                                                max          0.264
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.384
#                                                                max          0.253
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.391
#                                                                max          0.272
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.394
#                                                                max          0.278
#
# domain                                                                      Restt  \
# model       graph                                              postprocess
# flan-t5-xxl (None)                                             None         0.242
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.223
#                                                                max          0.364
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.207
#                                                                max          0.370
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.212
#                                                                max          0.372
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.213
#                                                                max          0.379
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.223
#                                                                max          0.366
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.215
#                                                                max          0.394
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.208
#                                                                max          0.407
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.212
#                                                                max          0.408
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.223
#                                                                max          0.367
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.226
#                                                                max          0.418
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.226
#                                                                max          0.418
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.227
#                                                                max          0.423
# gpt-turbo   (None)                                             None         0.481
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.510
#                                                                max          0.311
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.515
#                                                                max          0.324
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.517
#                                                                max          0.346
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.514
#                                                                max          0.345
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.512
#                                                                max          0.334
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.519
#                                                                max          0.341
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.517
#                                                                max          0.353
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.520
#                                                                max          0.357
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.520
#                                                                max          0.354
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.522
#                                                                max          0.361
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.526
#                                                                max          0.381
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.525
#                                                                max          0.391
#
# domain                                                                      Taxii  \
# model       graph                                              postprocess
# flan-t5-xxl (None)                                             None         0.026
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.197
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.232
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.238
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.234
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.218
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.214
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.253
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.260
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.218
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.238
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.253
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.026
#                                                                max          0.252
# gpt-turbo   (None)                                             None         0.515
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.512
#                                                                max          0.478
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.531
#                                                                max          0.456
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.561
#                                                                max          0.507
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.563
#                                                                max          0.482
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.527
#                                                                max          0.503
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.545
#                                                                max          0.488
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.565
#                                                                max          0.516
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.566
#                                                                max          0.508
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.527
#                                                                max          0.504
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.555
#                                                                max          0.499
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.565
#                                                                max          0.514
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.566
#                                                                max          0.514
#
# domain                                                                      Train
# model       graph                                              postprocess
# flan-t5-xxl (None)                                             None         0.085
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.053
#                                                                max          0.184
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.048
#                                                                max          0.193
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.044
#                                                                max          0.173
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.044
#                                                                max          0.178
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.049
#                                                                max          0.176
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.039
#                                                                max          0.199
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.034
#                                                                max          0.208
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.035
#                                                                max          0.221
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.049
#                                                                max          0.192
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.039
#                                                                max          0.189
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.039
#                                                                max          0.214
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.039
#                                                                max          0.208
# gpt-turbo   (None)                                             None         0.331
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.320
#                                                                max          0.270
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.321
#                                                                max          0.273
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.330
#                                                                max          0.267
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.331
#                                                                max          0.255
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.319
#                                                                max          0.271
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.319
#                                                                max          0.278
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.335
#                                                                max          0.272
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.353
#                                                                max          0.302
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.317
#                                                                max          0.271
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.322
#                                                                max          0.275
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.341
#                                                                max          0.308
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_... None         0.345
#                                                                max          0.314

# %% [markdown]
# ### 3. Prec and Rec

# %%
display_df = metrics_df.pivot_table(index=rows, columns=columns, values=['precision', 'recall'], aggfunc='mean')
display_df.round(3)
# Out:
#                                                                precision  \
# postprocess                                                         None
# model       graph
# flan-t5-xxl (None)                                                 0.388
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.463
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.491
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.515
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.506
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.475
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.495
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.503
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.509
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.488
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.494
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.492
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.498
# gpt-turbo   (None)                                                 0.436
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.556
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.599
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.604
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.600
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.569
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.598
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.603
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.592
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.564
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.582
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.579
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...     0.571
#
#                                                                       recall  \
# postprocess                                                       max   None
# model       graph
# flan-t5-xxl (None)                                                NaN  0.164
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.372  0.136
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.426  0.135
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.452  0.139
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.452  0.138
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.382  0.143
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.435  0.138
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.474  0.133
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.475  0.138
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.397  0.142
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.426  0.140
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.445  0.141
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.440  0.141
# gpt-turbo   (None)                                                NaN  0.501
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.478  0.415
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.517  0.402
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.545  0.419
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.546  0.420
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.496  0.427
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.518  0.414
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.538  0.421
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.559  0.438
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.490  0.424
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.512  0.424
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.532  0.439
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.537  0.446
#
#
# postprocess                                                       max
# model       graph
# flan-t5-xxl (None)                                                NaN
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.250
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.251
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.258
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.263
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.263
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.263
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.281
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.298
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.266
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.271
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.295
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.295
# gpt-turbo   (None)                                                NaN
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.298
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.264
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.300
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.287
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.315
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.290
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.291
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.302
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.313
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.306
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.332
#             inferred_graph_CSILP_fgam=0.95_bgam=0.9_cneg=4_...  0.338

# %% [markdown]
# ### 3. Paired t-test over all schema

# %%
display_df.query("graph == '(None)' and model == 'flan-t5-xxl'")
# Out:
#                    precision       recall
# postprocess             None max     None max
# model       graph
# flan-t5-xxl (None)  0.387579 NaN  0.16351 NaN

# %%
# ref: https://pythonfordatascienceorg.wordpress.com/paired-samples-t-test-python/
from scipy import stats
if mode == 1: # with/without graph for gpt & T5 on SGD
    model='gpt-turbo' # 'flan-t5-xxl'
    df1 = display_df.query(f"graph == '(None)' and model == '{model}'")
    df1 = df1.squeeze()
    df2 = display_df.query(f"graph == 'RILP' and model == '{model}'")
    df2 = df2.squeeze()
else:
    df1 = display_df.loc[display_df['graph']=='(None)']
    df2 = display_df.loc[display_df['graph']=='RILP']
stat, pval = stats.ttest_rel(df1, df2)
print(f'Mean before={df1.mean()} Mean after={df2.mean()}')
if df1.mean() < df2.mean():
    change_text = "increased"
else:
    change_text = "decreased"
print(f'pval = {pval}')
if pval < 0.05:
    print(f'Statistically significant {change_text} by {df2.mean() - df1.mean()}!')
else:
    print('Not significant')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'graph'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 10
#       8     df2 = df2.squeeze()
#       9 else:
# ---> 10     df1 = display_df.loc[display_df['graph']=='(None)']
#      11     df2 = display_df.loc[display_df['graph']=='RILP']
#      12 stat, pval = stats.ttest_rel(df1, df2)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/frame.py:3806, in DataFrame.__getitem__(self, key)
#    3804 if is_single_key:
#    3805     if self.columns.nlevels > 1:
# -> 3806         return self._getitem_multilevel(key)
#    3807     indexer = self.columns.get_loc(key)
#    3808     if is_integer(indexer):
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/frame.py:3857, in DataFrame._getitem_multilevel(self, key)
#    3855 def _getitem_multilevel(self, key):
#    3856     # self.columns is a MultiIndex
# -> 3857     loc = self.columns.get_loc(key)
#    3858     if isinstance(loc, (slice, np.ndarray)):
#    3859         new_columns = self.columns[loc]
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2916, in MultiIndex.get_loc(self, key, method)
#    2913     return mask
#    2915 if not isinstance(key, tuple):
# -> 2916     loc = self._get_level_indexer(key, level=0)
#    2917     return _maybe_to_slice(loc)
#    2919 keylen = len(key)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/indexes/multi.py:3263, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3259         return slice(i, j, step)
#    3261 else:
# -> 3263     idx = self._get_loc_single_level_index(level_index, key)
#    3265     if level > 0 or self._lexsort_depth == 0:
#    3266         # Desired level is not sorted
#    3267         if isinstance(idx, slice):
#    3268             # test_get_loc_partial_timestamp_multiindex
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2849, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2847     return -1
#    2848 else:
# -> 2849     return level_index.get_loc(key)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'graph'

# %%
t5_models=['flan-t5-xxl', 't5-xxl-lm-adapt']
mterics_t5 = metrics_df[metrics_df["model"].isin(t5_models)]
mterics_t5_5shot = mterics_t5[mterics_t5["shot"]==5]
display_df = mterics_t5_5shot.pivot(index=['model', 'graph'], columns=['domain'], values='f1')
rounded_df = display_df.round(decimals=3)
rounded_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 4
#       2 mterics_t5 = metrics_df[metrics_df["model"].isin(t5_models)]
#       3 mterics_t5_5shot = mterics_t5[mterics_t5["shot"]==5]
# ----> 4 display_df = mterics_t5_5shot.pivot(index=['model', 'graph'], columns=['domain'], values='f1')
#       5 rounded_df = display_df.round(decimals=3)
#       6 rounded_df
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/frame.py:8567, in DataFrame.pivot(self, index, columns, values)
#    8561 @Substitution("")
#    8562 @Appender(_shared_docs["pivot"])
#    8563 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])
#    8564 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    8565     from pandas.core.reshape.pivot import pivot
# -> 8567     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:540, in pivot(data, index, columns, values)
#     536         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     537 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     538 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     539 # "Hashable"
# --> 540 return indexed.unstack(columns_listlike)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/series.py:4455, in Series.unstack(self, level, fill_value)
#    4412 """
#    4413 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4414
#    (...)
#    4451 b    2    4
#    4452 """
#    4453 from pandas.core.reshape.reshape import unstack
# -> 4455 return unstack(self, level, fill_value)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:489, in unstack(obj, level, fill_value)
#     487 if is_1d_only_ea_dtype(obj.dtype):
#     488     return _unstack_extension_series(obj, level, fill_value)
# --> 489 unstacker = _Unstacker(
#     490     obj.index, level=level, constructor=obj._constructor_expanddim
#     491 )
#     492 return unstacker.get_result(
#     493     obj._values, value_columns=None, fill_value=fill_value
#     494 )
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:137, in _Unstacker.__init__(self, index, level, constructor)
#     129 if num_cells > np.iinfo(np.int32).max:
#     130     warnings.warn(
#     131         f"The following operation may generate {num_cells} cells "
#     132         f"in the resulting pandas object.",
#     133         PerformanceWarning,
#     134         stacklevel=find_stack_level(),
#     135     )
# --> 137 self._make_selectors()
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:189, in _Unstacker._make_selectors(self)
#     186 mask.put(selector, True)
#     188 if mask.sum() < len(self.index):
# --> 189     raise ValueError("Index contains duplicate entries, cannot reshape")
#     191 self.group_index = comp_index
#     192 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
print(metrics_df.pivot(index=['model', 'graph', 'shot'], columns=['domain'], values='f1').to_latex())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 print(metrics_df.pivot(index=['model', 'graph', 'shot'], columns=['domain'], values='f1').to_latex())
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/frame.py:8567, in DataFrame.pivot(self, index, columns, values)
#    8561 @Substitution("")
#    8562 @Appender(_shared_docs["pivot"])
#    8563 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])
#    8564 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    8565     from pandas.core.reshape.pivot import pivot
# -> 8567     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:540, in pivot(data, index, columns, values)
#     536         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     537 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     538 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     539 # "Hashable"
# --> 540 return indexed.unstack(columns_listlike)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/series.py:4455, in Series.unstack(self, level, fill_value)
#    4412 """
#    4413 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4414
#    (...)
#    4451 b    2    4
#    4452 """
#    4453 from pandas.core.reshape.reshape import unstack
# -> 4455 return unstack(self, level, fill_value)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:489, in unstack(obj, level, fill_value)
#     487 if is_1d_only_ea_dtype(obj.dtype):
#     488     return _unstack_extension_series(obj, level, fill_value)
# --> 489 unstacker = _Unstacker(
#     490     obj.index, level=level, constructor=obj._constructor_expanddim
#     491 )
#     492 return unstacker.get_result(
#     493     obj._values, value_columns=None, fill_value=fill_value
#     494 )
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:137, in _Unstacker.__init__(self, index, level, constructor)
#     129 if num_cells > np.iinfo(np.int32).max:
#     130     warnings.warn(
#     131         f"The following operation may generate {num_cells} cells "
#     132         f"in the resulting pandas object.",
#     133         PerformanceWarning,
#     134         stacklevel=find_stack_level(),
#     135     )
# --> 137 self._make_selectors()
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:189, in _Unstacker._make_selectors(self)
#     186 mask.put(selector, True)
#     188 if mask.sum() < len(self.index):
# --> 189     raise ValueError("Index contains duplicate entries, cannot reshape")
#     191 self.group_index = comp_index
#     192 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape
