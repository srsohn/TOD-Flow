# %%
import sys
sys.path.insert(0, '../src')
from pathlib import Path
import json
import os
import warnings
from tqdm import tqdm
import numpy as np
import pandas as pd

# %%
mode = 2
if mode is None:
    mode = 12 # 2: SGD / 12: MW
SHD_ALG_NAME = "SHDILP"
GRAPH_ALG_NAME = "CSILP"
#GRAPH_ALG_NAME = "BCILP"
#GRAPH_ALG_NAME = "MSG2"
FILTER="*"

DATASET = 'SGD' if mode <10 else 'MultiWOZ'
GRAPH_DATASET = 'SGD' if mode <10 else 'MultiWOZ'
INF_GRAPH_DIR = f'../graphs/{GRAPH_DATASET}/{GRAPH_ALG_NAME}'
SHD_DIR = f'../graphs/{GRAPH_DATASET}/{SHD_ALG_NAME}'
#
if mode < 10: # SGD
    PREDICTIONS_DIR = f'../outputs/{DATASET}/'   
else:
    PREDICTIONS_DIR = f'../outputs/MultiWOZ/'

# %%
def read_config(config_pth):
    try:
        with config_pth.open() as cf:
            config = json.load(cf)
    except Exception as e:
        print(f'Error while reading {config_pth}')
        print(e)
    #dataset = config['dataset']
    if '_trajectories.json' in config['traj_path']:
        config['domain'] = config['traj_path'].rsplit('/', 1)[-1].split('_trajectories.json')[0]
    else:
        config['domain'] = config['traj_path'].rsplit('/', 1)[-1].split('.json')[0]
    prompt = (config['prompt_style'], config['num_shot'], config['use_mask_prompt'])
    temp = 0.0 if 'temperature' not in config else config['temperature']
    sampling = 'multi' if 'sampling' not in config else config['sampling']
    
    key = [config['domain'], config['model'], prompt, temp, sampling]
    return config, key

# %% [markdown]
# ## Load predictions. Organize by the models

# %%
domains = set()
predictions, mapped_predictions = {}, {}
predictions_by_domain, label_tuple_by_domain = {}, {}
print(f'searching {len(list(Path(PREDICTIONS_DIR).glob(FILTER)))} directories @ {PREDICTIONS_DIR}')
for pth in Path(PREDICTIONS_DIR).glob(FILTER):
    for config_pth in pth.glob('config*.json'):
        config, base_key = read_config(config_pth)
        domains.add(config['domain'])
        for seed in config['seed']:
            key = tuple(base_key + [seed])
            for mapped_file_pth in config_pth.parent.glob(f'DM_mapped_prediction_S{seed}.npy'):
                if key in mapped_predictions:
                    assert False, f'duplicated: {key}, {mapped_file_pth}'
                try:
                    mapped_predictions[key] = np.load(mapped_file_pth, allow_pickle=True)
                    #print(f'loading @ {mapped_file_pth}')
                except Exception as e:
                    print(f'Error while reading {mapped_file_pth}', e)
        print(mapped_predictions.keys())
        label_tuple_by_domain[config['domain']] = (mapped_predictions[key][-2], mapped_predictions[key][-1])
assert len(mapped_predictions) % len(domains) == 0, "Number of predictions per domain is not consistent!"
print(f"Loaded {len(mapped_predictions)} files for {len(domains)} domains")
# Out:
# searching 4 directories @ ../outputs/SGD/
# dict_keys([('Events_2', 'flan-t5-xxl', ('entire-concise', 5, False), 1.0, 'multi', 1636423)])
# dict_keys([('Events_2', 'flan-t5-xxl', ('entire-concise', 5, False), 1.0, 'multi', 1636423), ('Events_2', 'flan-t5-xxl', ('entire-concise', 5, False), 0.0, 'multi', 1636423)])
# dict_keys([('Events_2', 'flan-t5-xxl', ('entire-concise', 5, False), 1.0, 'multi', 1636423), ('Events_2', 'flan-t5-xxl', ('entire-concise', 5, False), 0.0, 'multi', 1636423), ('Banks_1', 'flan-t5-xxl', ('entire-concise', 5, False), 1.0, 'multi', 1636423)])
# dict_keys([('Events_2', 'flan-t5-xxl', ('entire-concise', 5, False), 1.0, 'multi', 1636423), ('Events_2', 'flan-t5-xxl', ('entire-concise', 5, False), 0.0, 'multi', 1636423), ('Banks_1', 'flan-t5-xxl', ('entire-concise', 5, False), 1.0, 'multi', 1636423), ('Banks_1', 'flan-t5-xxl', ('entire-concise', 5, False), 0.0, 'multi', 1636423)])
# Loaded 4 files for 2 domains

# %% [markdown]
# ## Load inferred graphs

# %%
from util.graph_utils import get_graph_sop
def load_graphs(domains_list, root_dir, dataset, graph_alg_name, label_tuple_by_domain, is_should, filter="*"):
    load_count = 0
    num_graph_per_domain = []
    graphs = {}
    print(f'Loading {root_dir}/{dataset}_"domain"/*{graph_alg_name}{filter}.npy')
    for domain in domains_list:
        #print(f'loading @ {root_dir}/{dataset}_{domain}*/*{graph_alg_name}*.npy')
        all_acts, all_statuses = label_tuple_by_domain[domain]
        graph_algo_dict = {}
        matchings = list(Path(root_dir).glob(f'{dataset}_{domain}/*{graph_alg_name}{filter}.npy'))
        num_graph_per_domain.append(len(matchings))
        for matching in matchings:
            graph_path = str(matching)
            graph_raw = np.load(graph_path, allow_pickle=True).item()
            alg_name = graph_path.split('/')[-1].replace('.npy', '').replace("inferred_graph_", "")
            graph_sop = get_graph_sop(
                graph_raw,
                subtask_list=all_statuses,
                option_list=all_acts,
                empty_value=False if is_should else True
            )
            graph_algo_dict[alg_name] = graph_sop
            load_count += 1
        graphs[domain] = graph_algo_dict
    assert all([num_graph == num_graph_per_domain[0] for num_graph in num_graph_per_domain]), "Error. Num graph is different for each domain"
    return graphs, load_count

# %%
domains_list = list(domains)
#
print(INF_GRAPH_DIR)
is_should=False
graphs, load_count = load_graphs(domains_list, INF_GRAPH_DIR, DATASET, GRAPH_ALG_NAME, label_tuple_by_domain, is_should, filter="*")
print(f"Loaded {load_count} inferred CAN+SHDNT graphs from {len(domains)} domains")
#
print(SHD_DIR)
is_should=True
shd_sops, load_count = load_graphs(domains_list, SHD_DIR, DATASET, SHD_ALG_NAME, label_tuple_by_domain, is_should, filter="*")
print(f"Loaded {load_count} inferred SHD graphs from {len(domains)} domains")
#shd_sops = None
# Out:
# ../graphs/SGD/CCAOILP
# Loading ../graphs/SGD/CCAOILP/SGD_"domain"/*CCAOILP*.npy
# Loaded 2 inferred CAN+SHDNT graphs from 2 domains
# ../graphs/SGD/SHDILP
# Loading ../graphs/SGD/SHDILP/SGD_"domain"/*SHDILP*.npy
# Loaded 2 inferred SHD graphs from 2 domains

# %% [markdown]
# ## Calculate metrics

# %%
from multiprocess import Pool # use multiprocessing to speed up evaluation!

# %%
from util.eval_utils import dact_traj_metrics_report, dact_traj_multi_sample_metrics_report, standardize_dact
from copy import deepcopy

def eval_job(args):
    pred_params, graph_params, traj = args
    domain, model, prompt_params, temp, sampling, seed = pred_params
    prompt_style, num_shot, use_mask_prompt = prompt_params
    is_multisampling = float(temp) > 0 and ('repeat' not in sampling)
    graph_names, graph_tuples = graph_params
    graphs, neg_pcond_mats, should_sops = [], [], []
    for graph_tuple in graph_tuples:
        graph, should_sop = graph_tuple
        graphs.append(graph)
        neg_pcond_mats.append(None)
        should_sops.append(should_sop)
    
    if not isinstance(traj, tuple):
        gt_processed_label_tuple = tuple(traj)
    else:
        gt_processed_label_tuple = traj
    #print(f'In {pred_params} with multisampling={is_multisampling}')
    if is_multisampling:
        report_list = dact_traj_multi_sample_metrics_report(*gt_processed_label_tuple, graph_sop=graphs, neg_precond_mat=neg_pcond_mats, should_sops=should_sops, verbose=False)
    else:
        report_list = dact_traj_metrics_report(*gt_processed_label_tuple, graph_sop=graphs, neg_precond_mat=neg_pcond_mats, should_sops=should_sops, verbose=False)
    
    metrics_list = []
    #print(graph_names)
    for reprt, graph_name in zip(report_list,graph_names):
        if not isinstance(reprt, tuple):
            reprt = [reprt]
        for report in reprt:
            stats = report['Predicted']
            post = report['post']
            metrics = {
                'domain': domain[:4]+domain[-1],
                'model': model,
                'prompt': prompt_style,
                'shot': num_shot,
                'use_mask_prompt': use_mask_prompt,
                'temp': temp,
                'sampling': sampling,
                'seed': seed,
                'graph': graph_name,    
                'precision': stats['precision'],
                'recall': stats['recall'],
                'f1': stats['f1-score'],
                'support': stats['support'],
                'postprocess': post
            }
            metrics_list.append(metrics)
    return metrics_list
    
jobs = []
assert shd_sops is not None, "Error: SHOULD is empty"
for pred_params, mapped_pred_tuple in mapped_predictions.items():
    domain, model, prompt_params, temp, sampling, seed = pred_params
    #print(domain)
    #print(graphs)
    if temp > 0: # in case multi sampling, we cannot run without graph
        graph_list = list(graphs.get(domain, {}).items())
        shd_list = list(shd_sops.get(domain, {}).items())
    else:
        graph_list = list(graphs.get(domain, {}).items())
        shd_list = [('(None)', None)] + list(shd_sops.get(domain, {}).items())
    #print(graph_list)
    assert len(graph_list) == 1, "Error: current code cannot handle more than one precondition"
    can_graph = graph_list[0]
    """
    # ==== TEMPORARY DEBUGGING =====
    for i, shd in enumerate(shd_list):
        shd_sop_list = shd[1]
        if shd_sop_list is None: # no graph
            continue
        for j, sop in enumerate(shd_sop_list):
            shd_list[i][1][j] = False
        #print(f"[{domain}, {shd[0]}] {sum(is_shd_sop_none)} / {len(is_shd_sop_none)} should is None")
    # ==== TEMPORARY DEBUGGING =====
    """
    graph_names = [shd[0] for shd in shd_list]
    graph_tuples = [(can_graph[1], shd[1]) for shd in shd_list]
    #graph_tuples = [(can_graph[1], None) for shd in shd_list] # temporary: Exclude should
    #graph_tuples = [(None, shd[1]) for shd in shd_list] # temporary: should-only
    
    graph_params = (graph_names, graph_tuples)
    mapped_pred_tuple = mapped_pred_tuple[:-2] # remove last two: all_acts, all_statuses
    jobs.append((pred_params, graph_params, mapped_pred_tuple))
print(f"# jobs={len(jobs)}")

with Pool(min(60, len(jobs))) as p:
    raw_metrics = [result for result in tqdm(p.imap(eval_job, jobs)) if result is not None]
#raw_metrics = [eval_job(job) for job in jobs]
metrics = []
for elem in raw_metrics:
    for metric_dict in elem:
        metrics.append(metric_dict)
print(f"output={len(metrics)}")
# Out:
# # jobs=4
# 4it [00:00,  7.69it/s]
# output=12

# %%
org_metrics_df = pd.DataFrame(metrics)
metrics_df = org_metrics_df.copy()

nunique = metrics_df.nunique()
cols_to_drop = nunique[nunique == 1].index
metrics_df = metrics_df.drop(cols_to_drop, axis=1)

# %% [markdown]
# ### 1. Aggregated performance (averaged over schemas)

# %%
gpt_base_performance = 0.787513 if DATASET == 'SGD' else 0.446
t5_base_performance = 0.499171 if DATASET == 'SGD' else 0.304
base_performance = (gpt_base_performance + t5_base_performance) / 2
print(f"Mean={base_performance:.3f}, GPT={gpt_base_performance:.3f}, T5={t5_base_performance:.3f}")
# Out:
# Mean=0.643, GPT=0.788, T5=0.499

# %%
#rows = ['model', 'graph']
rows = ['graph']
columns = ['postprocess']
display_df = metrics_df.pivot_table(index=rows, columns=columns, values='f1', aggfunc='mean')
display_df
# Out:
# postprocess                            None     major       max   uniform  \
# graph
# (None)                             0.558660       NaN       NaN       NaN
# SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  0.795395  0.791888  0.741792  0.764794
#
# postprocess                        violation
# graph
# (None)                                   NaN
# SHDILP_bw=4_bd=4_cp=0.01_mins=0.9   0.768255

# %%
def parse_graph_hparam(hparam_str, param_names):
    tokens = hparam_str.split('_')
    hparam_dict = dict(algo=tokens[0])
    for par, token in zip(param_names, tokens[1:]):
        value = token.split('=')[1]
        try:
            hparam_dict[par] = int(value)
            continue
        except Exception as e:
            pass
        try:
            hparam_dict[par] = float(value)
            continue
        except Exception as e:
            pass
        hparam_dict[par] = value
    return hparam_dict

# %%
if mode % 10 == 2 or mode % 10 == 3:
    new_metrics = []
    for metric_dict in metrics:
        hparam_str = metric_dict['graph']
        if SHD_ALG_NAME == 'SHDILP': # inferred_graph_SHDILP_bw=4_bd=4_cp=0.01_mins=0.9
            param_names = ['bw', 'bd', 'cp', 'mins']
        hparam_dict = parse_graph_hparam(hparam_str, param_names)
        metric_dict.update(hparam_dict)
        new_metrics.append(metric_dict)
    print(f'[{SHD_ALG_NAME} @{DATASET}] num runs: {len(new_metrics)}')
    new_metrics_df = pd.DataFrame(new_metrics)
    graph_columns = param_names[1::2]
    graph_rows = param_names[::2]
    df_agg = new_metrics_df.pivot_table(index=graph_rows, columns=graph_columns, values='f1', aggfunc='mean')
    df_agg -= base_performance
    display(df_agg.round(decimals=3))
# Out:
# [SHDILP @SGD] num runs: 12
# bd          4.0
# mins        0.9
# bw  cp
# 4.0 0.01  0.129

# %%
df_group = new_metrics_df.groupby(graph_rows + graph_columns)
print(f"{num_domains * 2} == {list(df_group.size())} ?")
assert all([num_elem == num_domains * 2 for num_elem in df_group.size()])
#df_group.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[166], line 2
#       1 df_group = new_metrics_df.groupby(graph_rows + graph_columns)
# ----> 2 print(f"{num_domains * 2} == {list(df_group.size())} ?")
#       3 assert all([num_elem == num_domains * 2 for num_elem in df_group.size()])
#
# NameError: name 'num_domains' is not defined

# %%
if mode % 10 == 2:
    for hparam_label in param_names:
        new_df = new_metrics_df.groupby(hparam_label).agg('mean', numeric_only=True)['f1'].to_frame()
        new_df -= base_performance # subtract no graph performance
        if len(new_df.index) == 1 or hparam_label == 'model':
            continue
        display_df = new_df.T.round(decimals=3)
        display(display_df)
# Out:
# mins   0.60   0.70   0.80   0.83   0.85   0.87   0.90   0.93   0.95   0.97  \
# f1    0.102  0.102  0.102  0.102  0.102  0.102  0.102  0.102  0.102  0.102
#
# mins   1.00
# f1    0.102

# %%
graph_columns = ['model'] + param_names[1::2]
graph_columns = param_names[1::2]
graph_rows = ['model'] + param_names[::2]
df_agg2 = new_metrics_df.pivot_table(index=graph_rows, columns=graph_columns, values='f1', aggfunc='mean')
display(df_agg2.round(decimals=3))
# Out:
# bd                       4                                                   \
# mins                  0.60   0.70   0.80   0.83   0.85   0.87   0.90   0.93
# model       bw cp
# flan-t5-xxl 4  0.01  0.656  0.656  0.656  0.656  0.656  0.656  0.656  0.656
# gpt-turbo   4  0.01  0.835  0.835  0.835  0.835  0.835  0.835  0.835  0.835
#
# bd
# mins                  0.95   0.97   1.00
# model       bw cp
# flan-t5-xxl 4  0.01  0.656  0.656  0.656
# gpt-turbo   4  0.01  0.835  0.835  0.835

# %% [markdown]
# ### 2. schema-wise performance

# %%
from IPython.display import display
print(rows+columns)
display_df = metrics_df.pivot(index=rows+columns, columns=['domain'], values='f1')
display_df = display_df.round(3)
num_columns = len(display_df.columns)
if num_columns > 12:
    df1 = display_df.iloc[:, :num_columns//2]
    df2 = display_df.iloc[:, num_columns//2:]
    display(df1)
    display(df2)
else:
    display(display_df)
# Out:
# ['model', 'graph', 'postprocess']
# domain                                                      Bank1  Buse1  \
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.565  0.543
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.565  0.543
#                                                max          0.591  0.589
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.565  0.543
#                                                max          0.591  0.589
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.565  0.543
#                                                max          0.591  0.589
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.565  0.543
#                                                max          0.591  0.589
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.565  0.543
#                                                max          0.591  0.589
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.565  0.543
#                                                max          0.591  0.589
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.565  0.543
#                                                max          0.591  0.589
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.565  0.543
#                                                max          0.591  0.589
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.565  0.543
#                                                max          0.591  0.589
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.565  0.543
#                                                max          0.591  0.589
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.565  0.543
#                                                max          0.591  0.589
# gpt-turbo   (None)                             None         0.883  0.909
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.883  0.909
#                                                max          0.900  0.879
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.883  0.909
#                                                max          0.900  0.879
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.883  0.909
#                                                max          0.900  0.879
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.883  0.909
#                                                max          0.900  0.879
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.883  0.909
#                                                max          0.900  0.879
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.883  0.909
#                                                max          0.900  0.879
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.883  0.909
#                                                max          0.900  0.879
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.883  0.909
#                                                max          0.900  0.879
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.883  0.909
#                                                max          0.900  0.879
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.883  0.909
#                                                max          0.900  0.879
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.883  0.909
#                                                max          0.900  0.879
#
# domain                                                      Buse2  Cale1  \
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.582  0.378
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.582  0.378
#                                                max          0.642  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.582  0.378
#                                                max          0.642  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.582  0.378
#                                                max          0.642  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.582  0.378
#                                                max          0.642  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.582  0.378
#                                                max          0.642  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.582  0.378
#                                                max          0.642  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.582  0.378
#                                                max          0.642  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.582  0.378
#                                                max          0.642  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.582  0.378
#                                                max          0.642  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.582  0.378
#                                                max          0.642  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.582  0.378
#                                                max          0.642  0.586
# gpt-turbo   (None)                             None         0.895  0.857
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.895  0.857
#                                                max          0.884  0.875
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.895  0.857
#                                                max          0.884  0.875
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.895  0.857
#                                                max          0.884  0.875
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.895  0.857
#                                                max          0.884  0.875
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.895  0.857
#                                                max          0.884  0.875
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.895  0.857
#                                                max          0.884  0.875
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.895  0.857
#                                                max          0.884  0.875
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.895  0.857
#                                                max          0.884  0.875
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.895  0.857
#                                                max          0.884  0.875
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.895  0.857
#                                                max          0.884  0.875
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.895  0.857
#                                                max          0.884  0.875
#
# domain                                                      Even1  Even2  \
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.461  0.464
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.461  0.464
#                                                max          0.524  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.461  0.464
#                                                max          0.524  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.461  0.464
#                                                max          0.524  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.461  0.464
#                                                max          0.524  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.461  0.464
#                                                max          0.524  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.461  0.464
#                                                max          0.524  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.461  0.464
#                                                max          0.524  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.461  0.464
#                                                max          0.524  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.461  0.464
#                                                max          0.524  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.461  0.464
#                                                max          0.524  0.586
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.461  0.464
#                                                max          0.524  0.586
# gpt-turbo   (None)                             None         0.568  0.803
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.568  0.803
#                                                max          0.570  0.789
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.568  0.803
#                                                max          0.570  0.789
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.568  0.803
#                                                max          0.570  0.789
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.568  0.803
#                                                max          0.570  0.789
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.568  0.803
#                                                max          0.570  0.789
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.568  0.803
#                                                max          0.570  0.789
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.568  0.803
#                                                max          0.570  0.789
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.568  0.803
#                                                max          0.570  0.789
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.568  0.803
#                                                max          0.570  0.789
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.568  0.803
#                                                max          0.570  0.789
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.568  0.803
#                                                max          0.570  0.789
#
# domain                                                      Flig1  Flig2  \
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.217  0.685
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.217  0.685
#                                                max          0.389  0.674
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.217  0.685
#                                                max          0.389  0.674
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.217  0.685
#                                                max          0.389  0.674
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.217  0.685
#                                                max          0.389  0.674
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.217  0.685
#                                                max          0.389  0.674
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.217  0.685
#                                                max          0.389  0.674
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.217  0.685
#                                                max          0.389  0.674
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.217  0.685
#                                                max          0.389  0.674
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.217  0.685
#                                                max          0.389  0.674
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.217  0.685
#                                                max          0.389  0.674
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.217  0.685
#                                                max          0.389  0.674
# gpt-turbo   (None)                             None         0.804  0.838
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.804  0.838
#                                                max          0.751  0.834
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.804  0.838
#                                                max          0.751  0.834
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.804  0.838
#                                                max          0.751  0.834
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.804  0.838
#                                                max          0.751  0.834
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.804  0.838
#                                                max          0.751  0.834
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.804  0.838
#                                                max          0.751  0.834
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.804  0.838
#                                                max          0.751  0.834
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.804  0.838
#                                                max          0.751  0.834
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.804  0.838
#                                                max          0.751  0.834
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.804  0.838
#                                                max          0.751  0.834
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.804  0.838
#                                                max          0.751  0.834
#
# domain                                                      Home1  Hote1  \
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.813  0.613
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.813  0.613
#                                                max          0.845  0.642
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.813  0.613
#                                                max          0.845  0.642
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.813  0.613
#                                                max          0.845  0.642
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.813  0.613
#                                                max          0.845  0.642
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.813  0.613
#                                                max          0.845  0.642
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.813  0.613
#                                                max          0.845  0.642
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.813  0.613
#                                                max          0.845  0.642
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.813  0.613
#                                                max          0.845  0.642
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.813  0.613
#                                                max          0.845  0.642
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.813  0.613
#                                                max          0.845  0.642
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.813  0.613
#                                                max          0.845  0.642
# gpt-turbo   (None)                             None         0.869  0.842
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.869  0.842
#                                                max          0.847  0.815
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.869  0.842
#                                                max          0.847  0.815
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.869  0.842
#                                                max          0.847  0.815
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.869  0.842
#                                                max          0.847  0.815
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.869  0.842
#                                                max          0.847  0.815
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.869  0.842
#                                                max          0.847  0.815
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.869  0.842
#                                                max          0.847  0.815
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.869  0.842
#                                                max          0.847  0.815
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.869  0.842
#                                                max          0.847  0.815
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.869  0.842
#                                                max          0.847  0.815
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.869  0.842
#                                                max          0.847  0.815
#
# domain                                                      Hote2  Hote3
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.565  0.551
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.565  0.551
#                                                max          0.605  0.606
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.565  0.551
#                                                max          0.605  0.606
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.565  0.551
#                                                max          0.605  0.606
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.565  0.551
#                                                max          0.605  0.606
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.565  0.551
#                                                max          0.605  0.606
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.565  0.551
#                                                max          0.605  0.606
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.565  0.551
#                                                max          0.605  0.606
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.565  0.551
#                                                max          0.605  0.606
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.565  0.551
#                                                max          0.605  0.606
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.565  0.551
#                                                max          0.605  0.606
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.565  0.551
#                                                max          0.605  0.606
# gpt-turbo   (None)                             None         0.817  0.801
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.817  0.801
#                                                max          0.781  0.790
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.817  0.801
#                                                max          0.781  0.790
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.817  0.801
#                                                max          0.781  0.790
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.817  0.801
#                                                max          0.781  0.790
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.817  0.801
#                                                max          0.781  0.790
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.817  0.801
#                                                max          0.781  0.790
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.817  0.801
#                                                max          0.781  0.790
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.817  0.801
#                                                max          0.781  0.790
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.817  0.801
#                                                max          0.781  0.790
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.817  0.801
#                                                max          0.781  0.790
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.817  0.801
#                                                max          0.781  0.790
# domain                                                      Medi1  Movi1  \
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.778  0.681
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.778  0.681
#                                                max          0.814  0.730
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.778  0.681
#                                                max          0.814  0.730
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.778  0.681
#                                                max          0.814  0.730
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.778  0.681
#                                                max          0.814  0.730
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.778  0.681
#                                                max          0.814  0.730
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.778  0.681
#                                                max          0.814  0.730
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.778  0.681
#                                                max          0.814  0.730
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.778  0.681
#                                                max          0.814  0.730
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.778  0.681
#                                                max          0.814  0.730
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.778  0.681
#                                                max          0.814  0.730
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.778  0.681
#                                                max          0.814  0.730
# gpt-turbo   (None)                             None         0.903  0.878
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.903  0.878
#                                                max          0.900  0.854
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.903  0.878
#                                                max          0.900  0.854
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.903  0.878
#                                                max          0.900  0.854
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.903  0.878
#                                                max          0.900  0.854
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.903  0.878
#                                                max          0.900  0.854
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.903  0.878
#                                                max          0.900  0.854
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.903  0.878
#                                                max          0.900  0.854
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.903  0.878
#                                                max          0.900  0.854
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.903  0.878
#                                                max          0.900  0.854
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.903  0.878
#                                                max          0.900  0.854
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.903  0.878
#                                                max          0.900  0.854
#
# domain                                                      Musi1  Musi2  \
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.819  0.692
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.819  0.692
#                                                max          0.820  0.754
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.819  0.692
#                                                max          0.820  0.754
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.819  0.692
#                                                max          0.820  0.754
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.819  0.692
#                                                max          0.820  0.754
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.819  0.692
#                                                max          0.820  0.754
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.819  0.692
#                                                max          0.820  0.754
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.819  0.692
#                                                max          0.820  0.754
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.819  0.692
#                                                max          0.820  0.754
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.819  0.692
#                                                max          0.820  0.754
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.819  0.692
#                                                max          0.820  0.754
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.819  0.692
#                                                max          0.820  0.754
# gpt-turbo   (None)                             None         0.938  0.939
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.938  0.939
#                                                max          0.897  0.939
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.938  0.939
#                                                max          0.897  0.939
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.938  0.939
#                                                max          0.897  0.939
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.938  0.939
#                                                max          0.897  0.939
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.938  0.939
#                                                max          0.897  0.939
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.938  0.939
#                                                max          0.897  0.939
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.938  0.939
#                                                max          0.897  0.939
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.938  0.939
#                                                max          0.897  0.939
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.938  0.939
#                                                max          0.897  0.939
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.938  0.939
#                                                max          0.897  0.939
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.938  0.939
#                                                max          0.897  0.939
#
# domain                                                      Rent1  Rent2  \
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.361  0.450
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.361  0.450
#                                                max          0.502  0.489
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.361  0.450
#                                                max          0.502  0.489
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.361  0.450
#                                                max          0.502  0.489
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.361  0.450
#                                                max          0.502  0.489
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.361  0.450
#                                                max          0.502  0.489
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.361  0.450
#                                                max          0.502  0.489
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.361  0.450
#                                                max          0.502  0.489
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.361  0.450
#                                                max          0.502  0.489
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.361  0.450
#                                                max          0.502  0.489
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.361  0.450
#                                                max          0.502  0.489
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.361  0.450
#                                                max          0.502  0.489
# gpt-turbo   (None)                             None         0.918  0.833
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.918  0.833
#                                                max          0.937  0.853
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.918  0.833
#                                                max          0.937  0.853
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.918  0.833
#                                                max          0.937  0.853
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.918  0.833
#                                                max          0.937  0.853
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.918  0.833
#                                                max          0.937  0.853
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.918  0.833
#                                                max          0.937  0.853
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.918  0.833
#                                                max          0.937  0.853
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.918  0.833
#                                                max          0.937  0.853
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.918  0.833
#                                                max          0.937  0.853
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.918  0.833
#                                                max          0.937  0.853
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.918  0.833
#                                                max          0.937  0.853
#
# domain                                                      Rest1  Ride1  \
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.473  0.635
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.473  0.635
#                                                max          0.539  0.736
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.473  0.635
#                                                max          0.539  0.736
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.473  0.635
#                                                max          0.539  0.736
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.473  0.635
#                                                max          0.539  0.736
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.473  0.635
#                                                max          0.539  0.736
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.473  0.635
#                                                max          0.539  0.736
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.473  0.635
#                                                max          0.539  0.736
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.473  0.635
#                                                max          0.539  0.736
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.473  0.635
#                                                max          0.539  0.736
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.473  0.635
#                                                max          0.539  0.736
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.473  0.635
#                                                max          0.539  0.736
# gpt-turbo   (None)                             None         0.816  0.852
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.816  0.852
#                                                max          0.807  0.812
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.816  0.852
#                                                max          0.807  0.812
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.816  0.852
#                                                max          0.807  0.812
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.816  0.852
#                                                max          0.807  0.812
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.816  0.852
#                                                max          0.807  0.812
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.816  0.852
#                                                max          0.807  0.812
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.816  0.852
#                                                max          0.807  0.812
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.816  0.852
#                                                max          0.807  0.812
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.816  0.852
#                                                max          0.807  0.812
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.816  0.852
#                                                max          0.807  0.812
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.816  0.852
#                                                max          0.807  0.812
#
# domain                                                      Ride2  Serv1  \
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.561  0.692
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.561  0.692
#                                                max          0.824  0.807
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.561  0.692
#                                                max          0.824  0.807
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.561  0.692
#                                                max          0.824  0.807
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.561  0.692
#                                                max          0.824  0.807
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.561  0.692
#                                                max          0.824  0.807
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.561  0.692
#                                                max          0.824  0.807
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.561  0.692
#                                                max          0.824  0.807
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.561  0.692
#                                                max          0.824  0.807
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.561  0.692
#                                                max          0.824  0.807
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.561  0.692
#                                                max          0.824  0.807
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.561  0.692
#                                                max          0.824  0.807
# gpt-turbo   (None)                             None         0.796  0.741
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.796  0.741
#                                                max          0.759  0.746
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.796  0.741
#                                                max          0.759  0.746
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.796  0.741
#                                                max          0.759  0.746
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.796  0.741
#                                                max          0.759  0.746
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.796  0.741
#                                                max          0.759  0.746
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.796  0.741
#                                                max          0.759  0.746
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.796  0.741
#                                                max          0.759  0.746
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.796  0.741
#                                                max          0.759  0.746
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.796  0.741
#                                                max          0.759  0.746
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.796  0.741
#                                                max          0.759  0.746
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.796  0.741
#                                                max          0.759  0.746
#
# domain                                                      Serv2  Serv3
# model       graph                              postprocess
# flan-t5-xxl (None)                             None         0.734  0.704
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.734  0.704
#                                                max          0.733  0.718
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.734  0.704
#                                                max          0.733  0.718
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.734  0.704
#                                                max          0.733  0.718
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.734  0.704
#                                                max          0.733  0.718
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.734  0.704
#                                                max          0.733  0.718
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.734  0.704
#                                                max          0.733  0.718
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.734  0.704
#                                                max          0.733  0.718
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.734  0.704
#                                                max          0.733  0.718
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.734  0.704
#                                                max          0.733  0.718
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.734  0.704
#                                                max          0.733  0.718
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.734  0.704
#                                                max          0.733  0.718
# gpt-turbo   (None)                             None         0.795  0.756
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6  None         0.795  0.756
#                                                max          0.805  0.701
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7  None         0.795  0.756
#                                                max          0.805  0.701
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8  None         0.795  0.756
#                                                max          0.805  0.701
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83 None         0.795  0.756
#                                                max          0.805  0.701
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85 None         0.795  0.756
#                                                max          0.805  0.701
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87 None         0.795  0.756
#                                                max          0.805  0.701
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9  None         0.795  0.756
#                                                max          0.805  0.701
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93 None         0.795  0.756
#                                                max          0.805  0.701
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95 None         0.795  0.756
#                                                max          0.805  0.701
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97 None         0.795  0.756
#                                                max          0.805  0.701
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0  None         0.795  0.756
#                                                max          0.805  0.701

# %% [markdown]
# ### 3. Prec and Rec

# %%
display_df = metrics_df.pivot_table(index=rows, columns=columns, values=['precision', 'recall'], aggfunc='mean')
display_df.round(3)
# Out:
#                                                precision        recall
# postprocess                                         None    max   None    max
# model       graph
# flan-t5-xxl (None)                                 0.869    NaN  0.458    NaN
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6      0.869  0.732  0.458  0.603
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7      0.869  0.732  0.458  0.603
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8      0.869  0.732  0.458  0.603
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83     0.869  0.732  0.458  0.603
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85     0.869  0.732  0.458  0.603
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87     0.869  0.732  0.458  0.603
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9      0.869  0.732  0.458  0.603
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93     0.869  0.732  0.458  0.603
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95     0.869  0.732  0.458  0.603
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97     0.869  0.732  0.458  0.603
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0      0.869  0.732  0.458  0.603
# gpt-turbo   (None)                                 0.916    NaN  0.775    NaN
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.6      0.916  0.803  0.775  0.843
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.7      0.916  0.803  0.775  0.843
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.8      0.916  0.803  0.775  0.843
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.83     0.916  0.803  0.775  0.843
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.85     0.916  0.803  0.775  0.843
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.87     0.916  0.803  0.775  0.843
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.9      0.916  0.803  0.775  0.843
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.93     0.916  0.803  0.775  0.843
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.95     0.916  0.803  0.775  0.843
#             SHDILP_bw=4_bd=4_cp=0.01_mins=0.97     0.916  0.803  0.775  0.843
#             SHDILP_bw=4_bd=4_cp=0.01_mins=1.0      0.916  0.803  0.775  0.843

# %% [markdown]
# ### 3. Paired t-test over all schema

# %%
display_df.query("graph == '(None)' and model == 'flan-t5-xxl'")
# Out:
#                    precision        recall
# postprocess             None max      None max
# model       graph
# flan-t5-xxl (None)  0.868589 NaN  0.458327 NaN

# %%
# ref: https://pythonfordatascienceorg.wordpress.com/paired-samples-t-test-python/
from scipy import stats
if mode == 1: # with/without graph for gpt & T5 on SGD
    model='gpt-turbo' # 'flan-t5-xxl'
    df1 = display_df.query(f"graph == '(None)' and model == '{model}'")
    df1 = df1.squeeze()
    df2 = display_df.query(f"graph == 'RILP' and model == '{model}'")
    df2 = df2.squeeze()
else:
    df1 = display_df.loc[display_df['graph']=='(None)']
    df2 = display_df.loc[display_df['graph']=='RILP']
stat, pval = stats.ttest_rel(df1, df2)
print(f'Mean before={df1.mean()} Mean after={df2.mean()}')
if df1.mean() < df2.mean():
    change_text = "increased"
else:
    change_text = "decreased"
print(f'pval = {pval}')
if pval < 0.05:
    print(f'Statistically significant {change_text} by {df2.mean() - df1.mean()}!')
else:
    print('Not significant')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'graph'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 10
#       8     df2 = df2.squeeze()
#       9 else:
# ---> 10     df1 = display_df.loc[display_df['graph']=='(None)']
#      11     df2 = display_df.loc[display_df['graph']=='RILP']
#      12 stat, pval = stats.ttest_rel(df1, df2)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/frame.py:3806, in DataFrame.__getitem__(self, key)
#    3804 if is_single_key:
#    3805     if self.columns.nlevels > 1:
# -> 3806         return self._getitem_multilevel(key)
#    3807     indexer = self.columns.get_loc(key)
#    3808     if is_integer(indexer):
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/frame.py:3857, in DataFrame._getitem_multilevel(self, key)
#    3855 def _getitem_multilevel(self, key):
#    3856     # self.columns is a MultiIndex
# -> 3857     loc = self.columns.get_loc(key)
#    3858     if isinstance(loc, (slice, np.ndarray)):
#    3859         new_columns = self.columns[loc]
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2916, in MultiIndex.get_loc(self, key, method)
#    2913     return mask
#    2915 if not isinstance(key, tuple):
# -> 2916     loc = self._get_level_indexer(key, level=0)
#    2917     return _maybe_to_slice(loc)
#    2919 keylen = len(key)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/indexes/multi.py:3263, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3259         return slice(i, j, step)
#    3261 else:
# -> 3263     idx = self._get_loc_single_level_index(level_index, key)
#    3265     if level > 0 or self._lexsort_depth == 0:
#    3266         # Desired level is not sorted
#    3267         if isinstance(idx, slice):
#    3268             # test_get_loc_partial_timestamp_multiindex
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2849, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2847     return -1
#    2848 else:
# -> 2849     return level_index.get_loc(key)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'graph'

# %%
t5_models=['flan-t5-xxl', 't5-xxl-lm-adapt']
mterics_t5 = metrics_df[metrics_df["model"].isin(t5_models)]
mterics_t5_5shot = mterics_t5[mterics_t5["shot"]==5]
display_df = mterics_t5_5shot.pivot(index=['model', 'graph'], columns=['domain'], values='f1')
rounded_df = display_df.round(decimals=3)
rounded_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 4
#       2 mterics_t5 = metrics_df[metrics_df["model"].isin(t5_models)]
#       3 mterics_t5_5shot = mterics_t5[mterics_t5["shot"]==5]
# ----> 4 display_df = mterics_t5_5shot.pivot(index=['model', 'graph'], columns=['domain'], values='f1')
#       5 rounded_df = display_df.round(decimals=3)
#       6 rounded_df
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/frame.py:8567, in DataFrame.pivot(self, index, columns, values)
#    8561 @Substitution("")
#    8562 @Appender(_shared_docs["pivot"])
#    8563 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])
#    8564 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    8565     from pandas.core.reshape.pivot import pivot
# -> 8567     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:540, in pivot(data, index, columns, values)
#     536         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     537 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     538 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     539 # "Hashable"
# --> 540 return indexed.unstack(columns_listlike)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/series.py:4455, in Series.unstack(self, level, fill_value)
#    4412 """
#    4413 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4414
#    (...)
#    4451 b    2    4
#    4452 """
#    4453 from pandas.core.reshape.reshape import unstack
# -> 4455 return unstack(self, level, fill_value)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:489, in unstack(obj, level, fill_value)
#     487 if is_1d_only_ea_dtype(obj.dtype):
#     488     return _unstack_extension_series(obj, level, fill_value)
# --> 489 unstacker = _Unstacker(
#     490     obj.index, level=level, constructor=obj._constructor_expanddim
#     491 )
#     492 return unstacker.get_result(
#     493     obj._values, value_columns=None, fill_value=fill_value
#     494 )
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:137, in _Unstacker.__init__(self, index, level, constructor)
#     129 if num_cells > np.iinfo(np.int32).max:
#     130     warnings.warn(
#     131         f"The following operation may generate {num_cells} cells "
#     132         f"in the resulting pandas object.",
#     133         PerformanceWarning,
#     134         stacklevel=find_stack_level(),
#     135     )
# --> 137 self._make_selectors()
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:189, in _Unstacker._make_selectors(self)
#     186 mask.put(selector, True)
#     188 if mask.sum() < len(self.index):
# --> 189     raise ValueError("Index contains duplicate entries, cannot reshape")
#     191 self.group_index = comp_index
#     192 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
print(metrics_df.pivot(index=['model', 'graph', 'shot'], columns=['domain'], values='f1').to_latex())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 print(metrics_df.pivot(index=['model', 'graph', 'shot'], columns=['domain'], values='f1').to_latex())
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/frame.py:8567, in DataFrame.pivot(self, index, columns, values)
#    8561 @Substitution("")
#    8562 @Appender(_shared_docs["pivot"])
#    8563 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self"])
#    8564 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    8565     from pandas.core.reshape.pivot import pivot
# -> 8567     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:540, in pivot(data, index, columns, values)
#     536         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     537 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     538 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     539 # "Hashable"
# --> 540 return indexed.unstack(columns_listlike)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/series.py:4455, in Series.unstack(self, level, fill_value)
#    4412 """
#    4413 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4414
#    (...)
#    4451 b    2    4
#    4452 """
#    4453 from pandas.core.reshape.reshape import unstack
# -> 4455 return unstack(self, level, fill_value)
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:489, in unstack(obj, level, fill_value)
#     487 if is_1d_only_ea_dtype(obj.dtype):
#     488     return _unstack_extension_series(obj, level, fill_value)
# --> 489 unstacker = _Unstacker(
#     490     obj.index, level=level, constructor=obj._constructor_expanddim
#     491 )
#     492 return unstacker.get_result(
#     493     obj._values, value_columns=None, fill_value=fill_value
#     494 )
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:137, in _Unstacker.__init__(self, index, level, constructor)
#     129 if num_cells > np.iinfo(np.int32).max:
#     130     warnings.warn(
#     131         f"The following operation may generate {num_cells} cells "
#     132         f"in the resulting pandas object.",
#     133         PerformanceWarning,
#     134         stacklevel=find_stack_level(),
#     135     )
# --> 137 self._make_selectors()
#
# File ~/.miniconda3/envs/dialog/lib/python3.9/site-packages/pandas/core/reshape/reshape.py:189, in _Unstacker._make_selectors(self)
#     186 mask.put(selector, True)
#     188 if mask.sum() < len(self.index):
# --> 189     raise ValueError("Index contains duplicate entries, cannot reshape")
#     191 self.group_index = comp_index
#     192 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape
